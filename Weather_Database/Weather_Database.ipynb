# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
#3 Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#4 Get the nearest city using the citipy module.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
#5 Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e95daa8f1c10112e4ead5862b23b9cf3

# %%
#6 Retrieve the following information from the API call: Lat, lng, max temp, percent humidity,
# percent cloudiness, wind speed, weather desciption.

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lago da pedra
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | russell
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | saskylakh
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | antsohihy
# Processing Record 11 of Set 1 | hasaki
# Processing Record 12 of Set 1 | sturgeon bay
# Processing Record 13 of Set 1 | nyurba
# Processing Record 14 of Set 1 | temaraia
# City not found. Skipping...
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | ahipara
# Processing Record 17 of Set 1 | nikolskoye
# Processing Record 18 of Set 1 | urdzhar
# City not found. Skipping...
# Processing Record 19 of Set 1 | fortuna
# Processing Record 20 of Set 1 | sol-iletsk
# Processing Record 21 of Set 1 | harper
# Processing Record 22 of Set 1 | brazzaville
# Processing Record 23 of Set 1 | ostrovnoy
# Processing Record 24 of Set 1 | tessalit
# Processing Record 25 of Set 1 | havelock
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | tuktoyaktuk
# Processing Record 28 of Set 1 | dikson
# Processing Record 29 of Set 1 | tura
# Processing Record 30 of Set 1 | hami
# Processing Record 31 of Set 1 | lebu
# Processing Record 32 of Set 1 | izazi
# Processing Record 33 of Set 1 | kushima
# Processing Record 34 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 1 | bodden town
# Processing Record 36 of Set 1 | san quintin
# Processing Record 37 of Set 1 | severo-kurilsk
# Processing Record 38 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | new norfolk
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | lulea
# Processing Record 44 of Set 1 | tautira
# Processing Record 45 of Set 1 | san patricio
# Processing Record 46 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 1 | muros
# Processing Record 48 of Set 1 | tiksi
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 2 | georgetown
# Processing Record 3 of Set 2 | sukumo
# Processing Record 4 of Set 2 | chokurdakh
# Processing Record 5 of Set 2 | port hardy
# Processing Record 6 of Set 2 | khatanga
# Processing Record 7 of Set 2 | mount isa
# Processing Record 8 of Set 2 | bredasdorp
# Processing Record 9 of Set 2 | deputatskiy
# Processing Record 10 of Set 2 | longyearbyen
# Processing Record 11 of Set 2 | pacific grove
# Processing Record 12 of Set 2 | chuy
# Processing Record 13 of Set 2 | busselton
# Processing Record 14 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 2 | mishan
# Processing Record 16 of Set 2 | lorengau
# Processing Record 17 of Set 2 | oum hadjer
# Processing Record 18 of Set 2 | kodiak
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | kapaa
# Processing Record 21 of Set 2 | thompson
# Processing Record 22 of Set 2 | yoichi
# Processing Record 23 of Set 2 | kieta
# Processing Record 24 of Set 2 | nanortalik
# Processing Record 25 of Set 2 | powassan
# Processing Record 26 of Set 2 | pokhara
# Processing Record 27 of Set 2 | saint-joseph
# Processing Record 28 of Set 2 | kaitangata
# Processing Record 29 of Set 2 | lamu
# Processing Record 30 of Set 2 | estelle
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | avera
# Processing Record 33 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 34 of Set 2 | san cristobal
# Processing Record 35 of Set 2 | shingu
# Processing Record 36 of Set 2 | faanui
# Processing Record 37 of Set 2 | namibe
# Processing Record 38 of Set 2 | luderitz
# Processing Record 39 of Set 2 | bluff
# Processing Record 40 of Set 2 | iqaluit
# Processing Record 41 of Set 2 | haines junction
# Processing Record 42 of Set 2 | upernavik
# Processing Record 43 of Set 2 | aklavik
# Processing Record 44 of Set 2 | jutai
# Processing Record 45 of Set 2 | chapleau
# Processing Record 46 of Set 2 | touros
# Processing Record 47 of Set 2 | dalnegorsk
# Processing Record 48 of Set 2 | saint-philippe
# Processing Record 49 of Set 2 | batemans bay
# Processing Record 50 of Set 2 | yumen
# Processing Record 1 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 3 | berdigestyakh
# Processing Record 3 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 3 | mar del plata
# Processing Record 5 of Set 3 | stoyba
# City not found. Skipping...
# Processing Record 6 of Set 3 | mocuba
# Processing Record 7 of Set 3 | mchinji
# Processing Record 8 of Set 3 | nandura
# Processing Record 9 of Set 3 | meadville
# Processing Record 10 of Set 3 | necochea
# Processing Record 11 of Set 3 | port elizabeth
# Processing Record 12 of Set 3 | east london
# Processing Record 13 of Set 3 | cherskiy
# Processing Record 14 of Set 3 | mahebourg
# Processing Record 15 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 3 | bonavista
# Processing Record 17 of Set 3 | ketchikan
# Processing Record 18 of Set 3 | safaqis
# City not found. Skipping...
# Processing Record 19 of Set 3 | viru
# Processing Record 20 of Set 3 | aras
# Processing Record 21 of Set 3 | nome
# Processing Record 22 of Set 3 | broken hill
# Processing Record 23 of Set 3 | cayenne
# Processing Record 24 of Set 3 | calabozo
# Processing Record 25 of Set 3 | ponta do sol
# Processing Record 26 of Set 3 | saurimo
# Processing Record 27 of Set 3 | berlevag
# Processing Record 28 of Set 3 | dauphin
# Processing Record 29 of Set 3 | sao filipe
# Processing Record 30 of Set 3 | dayong
# Processing Record 31 of Set 3 | marystown
# Processing Record 32 of Set 3 | codrington
# Processing Record 33 of Set 3 | anadyr
# Processing Record 34 of Set 3 | hambantota
# Processing Record 35 of Set 3 | castro
# Processing Record 36 of Set 3 | onda
# Processing Record 37 of Set 3 | menongue
# Processing Record 38 of Set 3 | mirabad
# Processing Record 39 of Set 3 | congonhas
# Processing Record 40 of Set 3 | dzilam gonzalez
# Processing Record 41 of Set 3 | parfenyevo
# Processing Record 42 of Set 3 | changji
# Processing Record 43 of Set 3 | la roche-sur-yon
# Processing Record 44 of Set 3 | isangel
# Processing Record 45 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 46 of Set 3 | chumikan
# Processing Record 47 of Set 3 | almaznyy
# Processing Record 48 of Set 3 | ngunguru
# Processing Record 49 of Set 3 | huarmey
# Processing Record 50 of Set 3 | derzhavinsk
# Processing Record 1 of Set 4 | redmond
# Processing Record 2 of Set 4 | kavieng
# Processing Record 3 of Set 4 | tarko-sale
# Processing Record 4 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 4 | setermoen
# Processing Record 6 of Set 4 | onomichi
# Processing Record 7 of Set 4 | talnakh
# Processing Record 8 of Set 4 | prachuap khiri khan
# Processing Record 9 of Set 4 | iroquois falls
# Processing Record 10 of Set 4 | leningradskiy
# Processing Record 11 of Set 4 | lagoa
# Processing Record 12 of Set 4 | jabinyanah
# Processing Record 13 of Set 4 | ribeira grande
# Processing Record 14 of Set 4 | klaksvik
# Processing Record 15 of Set 4 | hilo
# Processing Record 16 of Set 4 | sault sainte marie
# Processing Record 17 of Set 4 | katsuura
# Processing Record 18 of Set 4 | narsaq
# Processing Record 19 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 4 | acari
# Processing Record 22 of Set 4 | akdagmadeni
# Processing Record 23 of Set 4 | coquimbo
# Processing Record 24 of Set 4 | khandyga
# Processing Record 25 of Set 4 | provideniya
# Processing Record 26 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 4 | mataura
# Processing Record 28 of Set 4 | severnyy
# Processing Record 29 of Set 4 | jalu
# Processing Record 30 of Set 4 | harsud
# Processing Record 31 of Set 4 | ixtapa
# Processing Record 32 of Set 4 | beira
# Processing Record 33 of Set 4 | chicama
# Processing Record 34 of Set 4 | at-bashi
# Processing Record 35 of Set 4 | carnarvon
# Processing Record 36 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 4 | edeia
# Processing Record 38 of Set 4 | butaritari
# Processing Record 39 of Set 4 | souillac
# Processing Record 40 of Set 4 | paris
# Processing Record 41 of Set 4 | aripuana
# Processing Record 42 of Set 4 | modra
# Processing Record 43 of Set 4 | asau
# Processing Record 44 of Set 4 | cabo san lucas
# Processing Record 45 of Set 4 | vao
# Processing Record 46 of Set 4 | millinocket
# Processing Record 47 of Set 4 | jasper
# Processing Record 48 of Set 4 | kaifeng
# Processing Record 49 of Set 4 | cidreira
# Processing Record 50 of Set 4 | sistranda
# Processing Record 1 of Set 5 | qingan
# City not found. Skipping...
# Processing Record 2 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 5 | mukhen
# Processing Record 4 of Set 5 | quata
# Processing Record 5 of Set 5 | viedma
# Processing Record 6 of Set 5 | ilulissat
# Processing Record 7 of Set 5 | qaanaaq
# Processing Record 8 of Set 5 | oktyabrskiy
# Processing Record 9 of Set 5 | olafsvik
# Processing Record 10 of Set 5 | aracaju
# Processing Record 11 of Set 5 | hukuntsi
# Processing Record 12 of Set 5 | san policarpo
# Processing Record 13 of Set 5 | esperance
# Processing Record 14 of Set 5 | itarema
# Processing Record 15 of Set 5 | cockburn town
# Processing Record 16 of Set 5 | mount gambier
# Processing Record 17 of Set 5 | miguel calmon
# Processing Record 18 of Set 5 | beroroha
# Processing Record 19 of Set 5 | port alfred
# Processing Record 20 of Set 5 | sobolevo
# Processing Record 21 of Set 5 | airai
# Processing Record 22 of Set 5 | show low
# Processing Record 23 of Set 5 | yeniseysk
# Processing Record 24 of Set 5 | kafue
# Processing Record 25 of Set 5 | yongan
# Processing Record 26 of Set 5 | milkovo
# Processing Record 27 of Set 5 | baker city
# Processing Record 28 of Set 5 | papillion
# Processing Record 29 of Set 5 | bosaso
# Processing Record 30 of Set 5 | hervey bay
# Processing Record 31 of Set 5 | barcelos
# Processing Record 32 of Set 5 | victoria
# Processing Record 33 of Set 5 | norman wells
# Processing Record 34 of Set 5 | smiths falls
# Processing Record 35 of Set 5 | uddevalla
# Processing Record 36 of Set 5 | salalah
# Processing Record 37 of Set 5 | pevek
# Processing Record 38 of Set 5 | saint george
# Processing Record 39 of Set 5 | pisco
# Processing Record 40 of Set 5 | khasan
# Processing Record 41 of Set 5 | tingrela
# City not found. Skipping...
# Processing Record 42 of Set 5 | baykit
# Processing Record 43 of Set 5 | odemis
# City not found. Skipping...
# Processing Record 44 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 5 | luau
# Processing Record 46 of Set 5 | camana
# Processing Record 47 of Set 5 | waddan
# Processing Record 48 of Set 5 | acapulco
# Processing Record 49 of Set 5 | namatanai
# Processing Record 50 of Set 5 | barao de cocais
# Processing Record 1 of Set 6 | hongjiang
# Processing Record 2 of Set 6 | port augusta
# Processing Record 3 of Set 6 | hobyo
# Processing Record 4 of Set 6 | baft
# Processing Record 5 of Set 6 | ust-kuyga
# Processing Record 6 of Set 6 | copiapo
# Processing Record 7 of Set 6 | burley
# Processing Record 8 of Set 6 | tazovskiy
# Processing Record 9 of Set 6 | college
# Processing Record 10 of Set 6 | varnavino
# Processing Record 11 of Set 6 | sao sebastiao
# Processing Record 12 of Set 6 | chimore
# Processing Record 13 of Set 6 | naze
# Processing Record 14 of Set 6 | upata
# Processing Record 15 of Set 6 | kruisfontein
# Processing Record 16 of Set 6 | morondava
# Processing Record 17 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 6 | kuytun
# Processing Record 19 of Set 6 | vestmanna
# Processing Record 20 of Set 6 | westport
# Processing Record 21 of Set 6 | fort smith
# Processing Record 22 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 23 of Set 6 | honiara
# Processing Record 24 of Set 6 | black river
# Processing Record 25 of Set 6 | kavaratti
# Processing Record 26 of Set 6 | yar-sale
# Processing Record 27 of Set 6 | buraydah
# Processing Record 28 of Set 6 | guerrero negro
# Processing Record 29 of Set 6 | jarjis
# City not found. Skipping...
# Processing Record 30 of Set 6 | umm lajj
# Processing Record 31 of Set 6 | hvolsvollur
# Processing Record 32 of Set 6 | geraldton
# Processing Record 33 of Set 6 | katangli
# Processing Record 34 of Set 6 | praia
# Processing Record 35 of Set 6 | avarua
# Processing Record 36 of Set 6 | bathsheba
# Processing Record 37 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 6 | sabang
# Processing Record 39 of Set 6 | antofagasta
# Processing Record 40 of Set 6 | flin flon
# Processing Record 41 of Set 6 | mehamn
# Processing Record 42 of Set 6 | les cayes
# Processing Record 43 of Set 6 | marion
# Processing Record 44 of Set 6 | yanchukan
# City not found. Skipping...
# Processing Record 45 of Set 6 | qostanay
# Processing Record 46 of Set 6 | caravelas
# Processing Record 47 of Set 6 | labuhan
# Processing Record 48 of Set 6 | hokitika
# Processing Record 49 of Set 6 | erdenet
# Processing Record 50 of Set 6 | norwich
# Processing Record 1 of Set 7 | santa ines
# Processing Record 2 of Set 7 | vardo
# Processing Record 3 of Set 7 | kutum
# Processing Record 4 of Set 7 | tomatlan
# Processing Record 5 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 7 | prescott valley
# Processing Record 7 of Set 7 | rosarito
# Processing Record 8 of Set 7 | bambous virieux
# Processing Record 9 of Set 7 | los llanos de aridane
# Processing Record 10 of Set 7 | jalingo
# Processing Record 11 of Set 7 | vostok
# Processing Record 12 of Set 7 | alice springs
# Processing Record 13 of Set 7 | idlib
# Processing Record 14 of Set 7 | pangkalanbuun
# Processing Record 15 of Set 7 | truth or consequences
# Processing Record 16 of Set 7 | tukrah
# Processing Record 17 of Set 7 | kurilsk
# Processing Record 18 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 7 | torbay
# Processing Record 20 of Set 7 | huilong
# Processing Record 21 of Set 7 | bowmore
# Processing Record 22 of Set 7 | bethel
# Processing Record 23 of Set 7 | mariental
# Processing Record 24 of Set 7 | bitung
# Processing Record 25 of Set 7 | camargo
# Processing Record 26 of Set 7 | bengkulu
# Processing Record 27 of Set 7 | manado
# Processing Record 28 of Set 7 | nouadhibou
# Processing Record 29 of Set 7 | gurupa
# Processing Record 30 of Set 7 | daru
# Processing Record 31 of Set 7 | quatre cocos
# Processing Record 32 of Set 7 | disna
# Processing Record 33 of Set 7 | saraland
# Processing Record 34 of Set 7 | chapais
# Processing Record 35 of Set 7 | constitucion
# Processing Record 36 of Set 7 | mitchell
# Processing Record 37 of Set 7 | zurich
# Processing Record 38 of Set 7 | traipu
# Processing Record 39 of Set 7 | taicheng
# Processing Record 40 of Set 7 | kalamakion
# City not found. Skipping...
# Processing Record 41 of Set 7 | castro marim
# Processing Record 42 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 43 of Set 7 | pochutla
# Processing Record 44 of Set 7 | ndioum
# Processing Record 45 of Set 7 | beringovskiy
# Processing Record 46 of Set 7 | baglung
# Processing Record 47 of Set 7 | kiruna
# Processing Record 48 of Set 7 | rangapara
# Processing Record 49 of Set 7 | alofi
# Processing Record 50 of Set 7 | marzuq
# Processing Record 1 of Set 8 | flinders
# Processing Record 2 of Set 8 | coracao de jesus
# Processing Record 3 of Set 8 | kahului
# Processing Record 4 of Set 8 | clyde river
# Processing Record 5 of Set 8 | virarajendrapet
# Processing Record 6 of Set 8 | shimoda
# Processing Record 7 of Set 8 | shihezi
# Processing Record 8 of Set 8 | lesnoy
# Processing Record 9 of Set 8 | muli
# Processing Record 10 of Set 8 | ouadda
# Processing Record 11 of Set 8 | comodoro rivadavia
# Processing Record 12 of Set 8 | tokmak
# Processing Record 13 of Set 8 | altamira
# Processing Record 14 of Set 8 | sibu
# Processing Record 15 of Set 8 | marabba
# Processing Record 16 of Set 8 | mayo
# Processing Record 17 of Set 8 | livadiya
# Processing Record 18 of Set 8 | gornouralskiy
# City not found. Skipping...
# Processing Record 19 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 20 of Set 8 | rancagua
# Processing Record 21 of Set 8 | fukue
# Processing Record 22 of Set 8 | palmer
# Processing Record 23 of Set 8 | panyutyne
# Processing Record 24 of Set 8 | kaputa
# Processing Record 25 of Set 8 | rock sound
# Processing Record 26 of Set 8 | vila velha
# Processing Record 27 of Set 8 | ponta delgada
# Processing Record 28 of Set 8 | lyubytino
# Processing Record 29 of Set 8 | kudahuvadhoo
# Processing Record 30 of Set 8 | honningsvag
# Processing Record 31 of Set 8 | dubbo
# Processing Record 32 of Set 8 | blensong
# City not found. Skipping...
# Processing Record 33 of Set 8 | okmulgee
# Processing Record 34 of Set 8 | rapid valley
# Processing Record 35 of Set 8 | achacachi
# Processing Record 36 of Set 8 | kalaleh
# Processing Record 37 of Set 8 | kloulklubed
# Processing Record 38 of Set 8 | saldanha
# Processing Record 39 of Set 8 | kollam
# Processing Record 40 of Set 8 | santiago del estero
# Processing Record 41 of Set 8 | lac du bonnet
# Processing Record 42 of Set 8 | katobu
# Processing Record 43 of Set 8 | kropotkin
# Processing Record 44 of Set 8 | valledupar
# Processing Record 45 of Set 8 | naryan-mar
# Processing Record 46 of Set 8 | tsienyane
# City not found. Skipping...
# Processing Record 47 of Set 8 | desbiens
# Processing Record 48 of Set 8 | tasiilaq
# Processing Record 49 of Set 8 | kapustin yar-1
# City not found. Skipping...
# Processing Record 50 of Set 8 | saint-augustin
# Processing Record 1 of Set 9 | korhogo
# Processing Record 2 of Set 9 | tiarei
# Processing Record 3 of Set 9 | fairmont
# Processing Record 4 of Set 9 | altay
# Processing Record 5 of Set 9 | tuatapere
# Processing Record 6 of Set 9 | scarborough
# Processing Record 7 of Set 9 | payo
# Processing Record 8 of Set 9 | dawei
# Processing Record 9 of Set 9 | portobelo
# Processing Record 10 of Set 9 | margate
# Processing Record 11 of Set 9 | punakha
# Processing Record 12 of Set 9 | matamoros
# Processing Record 13 of Set 9 | bolobo
# Processing Record 14 of Set 9 | diu
# Processing Record 15 of Set 9 | suntar
# Processing Record 16 of Set 9 | nishihara
# Processing Record 17 of Set 9 | manggar
# Processing Record 18 of Set 9 | inhambane
# Processing Record 19 of Set 9 | otuzco
# Processing Record 20 of Set 9 | usinsk
# Processing Record 21 of Set 9 | pangai
# Processing Record 22 of Set 9 | shakawe
# Processing Record 23 of Set 9 | fare
# Processing Record 24 of Set 9 | raudeberg
# Processing Record 25 of Set 9 | santa maria da vitoria
# Processing Record 26 of Set 9 | khormuj
# City not found. Skipping...
# Processing Record 27 of Set 9 | san carlos de bariloche
# Processing Record 28 of Set 9 | yulara
# Processing Record 29 of Set 9 | toora-khem
# Processing Record 30 of Set 9 | te anau
# Processing Record 31 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 32 of Set 9 | waingapu
# Processing Record 33 of Set 9 | noyabrsk
# Processing Record 34 of Set 9 | higuey
# City not found. Skipping...
# Processing Record 35 of Set 9 | san angelo
# Processing Record 36 of Set 9 | hualmay
# Processing Record 37 of Set 9 | maromitsa
# Processing Record 38 of Set 9 | mecca
# Processing Record 39 of Set 9 | taraz
# Processing Record 40 of Set 9 | ocos
# Processing Record 41 of Set 9 | sri aman
# Processing Record 42 of Set 9 | komsomolskiy
# Processing Record 43 of Set 9 | kenora
# Processing Record 44 of Set 9 | balkanabat
# Processing Record 45 of Set 9 | hovd
# Processing Record 46 of Set 9 | deep river
# Processing Record 47 of Set 9 | lasa
# Processing Record 48 of Set 9 | grand gaube
# Processing Record 49 of Set 9 | kosa
# Processing Record 50 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 1 of Set 10 | oistins
# Processing Record 2 of Set 10 | richards bay
# Processing Record 3 of Set 10 | san blas
# Processing Record 4 of Set 10 | tabriz
# Processing Record 5 of Set 10 | darhan
# Processing Record 6 of Set 10 | la ronge
# Processing Record 7 of Set 10 | kenai
# Processing Record 8 of Set 10 | russkaya polyana
# Processing Record 9 of Set 10 | eureka
# Processing Record 10 of Set 10 | kampong thum
# Processing Record 11 of Set 10 | ayan
# Processing Record 12 of Set 10 | zabol
# Processing Record 13 of Set 10 | tansen
# Processing Record 14 of Set 10 | george
# Processing Record 15 of Set 10 | lucapa
# Processing Record 16 of Set 10 | luanda
# Processing Record 17 of Set 10 | gat
# Processing Record 18 of Set 10 | piacabucu
# Processing Record 19 of Set 10 | talaya
# Processing Record 20 of Set 10 | nisia floresta
# Processing Record 21 of Set 10 | abalak
# Processing Record 22 of Set 10 | port lincoln
# Processing Record 23 of Set 10 | bairiki
# Processing Record 24 of Set 10 | la rioja
# Processing Record 25 of Set 10 | evensk
# Processing Record 26 of Set 10 | ereymentau
# Processing Record 27 of Set 10 | romitan
# Processing Record 28 of Set 10 | igarka
# Processing Record 29 of Set 10 | general cepeda
# Processing Record 30 of Set 10 | dongsheng
# Processing Record 31 of Set 10 | swift current
# Processing Record 32 of Set 10 | sao joao da barra
# Processing Record 33 of Set 10 | bilma
# Processing Record 34 of Set 10 | muskegon
# Processing Record 35 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 36 of Set 10 | wattegama
# Processing Record 37 of Set 10 | chamarel
# City not found. Skipping...
# Processing Record 38 of Set 10 | virginia beach
# Processing Record 39 of Set 10 | fairbanks
# Processing Record 40 of Set 10 | burica
# City not found. Skipping...
# Processing Record 41 of Set 10 | juneau
# Processing Record 42 of Set 10 | sidi ali
# Processing Record 43 of Set 10 | nemuro
# Processing Record 44 of Set 10 | camacha
# Processing Record 45 of Set 10 | kirakira
# Processing Record 46 of Set 10 | yenagoa
# Processing Record 47 of Set 10 | sorland
# Processing Record 48 of Set 10 | jaque
# Processing Record 49 of Set 10 | tucupita
# Processing Record 50 of Set 10 | hofn
# Processing Record 1 of Set 11 | port blair
# Processing Record 2 of Set 11 | florence
# Processing Record 3 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 11 | goundam
# Processing Record 5 of Set 11 | karpuninskiy
# City not found. Skipping...
# Processing Record 6 of Set 11 | grindavik
# Processing Record 7 of Set 11 | lapua
# Processing Record 8 of Set 11 | slave lake
# Processing Record 9 of Set 11 | bambanglipuro
# Processing Record 10 of Set 11 | byron bay
# Processing Record 11 of Set 11 | ilinge
# Processing Record 12 of Set 11 | la asuncion
# Processing Record 13 of Set 11 | siavonga
# Processing Record 14 of Set 11 | svetlogorsk
# Processing Record 15 of Set 11 | kismayo
# Processing Record 16 of Set 11 | mbekenyera
# Processing Record 17 of Set 11 | kijaba
# City not found. Skipping...
# Processing Record 18 of Set 11 | sindor
# Processing Record 19 of Set 11 | amazar
# Processing Record 20 of Set 11 | doha
# Processing Record 21 of Set 11 | sinjar
# Processing Record 22 of Set 11 | skhisma
# Processing Record 23 of Set 11 | graaff-reinet
# Processing Record 24 of Set 11 | belaya gora
# Processing Record 25 of Set 11 | northam
# Processing Record 26 of Set 11 | kapuskasing
# Processing Record 27 of Set 11 | pangnirtung
# Processing Record 28 of Set 11 | sindou
# Processing Record 29 of Set 11 | qaqortoq
# Processing Record 30 of Set 11 | yaan
# Processing Record 31 of Set 11 | tingi
# Processing Record 32 of Set 11 | kamina
# Processing Record 33 of Set 11 | temiscaming
# Processing Record 34 of Set 11 | atambua
# Processing Record 35 of Set 11 | nenjiang
# Processing Record 36 of Set 11 | sitka
# Processing Record 37 of Set 11 | douentza
# Processing Record 38 of Set 11 | moree
# Processing Record 39 of Set 11 | henzada
# City not found. Skipping...
# Processing Record 40 of Set 11 | husavik
# Processing Record 41 of Set 11 | madimba
# Processing Record 42 of Set 11 | chaltyr
# Processing Record 43 of Set 11 | qandala
# Processing Record 44 of Set 11 | hit
# Processing Record 45 of Set 11 | nagai
# Processing Record 46 of Set 11 | linhares
# Processing Record 47 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 48 of Set 11 | tongzi
# Processing Record 49 of Set 11 | nyazepetrovsk
# Processing Record 50 of Set 11 | seoul
# Processing Record 1 of Set 12 | olinda
# Processing Record 2 of Set 12 | ayorou
# Processing Record 3 of Set 12 | shelburne
# Processing Record 4 of Set 12 | kizner
# Processing Record 5 of Set 12 | valparaiso
# Processing Record 6 of Set 12 | mizan teferi
# Processing Record 7 of Set 12 | orange cove
# Processing Record 8 of Set 12 | forest grove
# Processing Record 9 of Set 12 | aswan
# Processing Record 10 of Set 12 | severodvinsk
# Processing Record 11 of Set 12 | lokosovo
# Processing Record 12 of Set 12 | lavrentiya
# Processing Record 13 of Set 12 | kalabugao
# City not found. Skipping...
# Processing Record 14 of Set 12 | fort frances
# Processing Record 15 of Set 12 | verkhoyansk
# Processing Record 16 of Set 12 | dalby
# Processing Record 17 of Set 12 | buala
# Processing Record 18 of Set 12 | yakeshi
# Processing Record 19 of Set 12 | siteki
# Processing Record 20 of Set 12 | broome
# Processing Record 21 of Set 12 | weyburn
# Processing Record 22 of Set 12 | havoysund
# Processing Record 23 of Set 12 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 24 of Set 12 | neepawa
# Processing Record 25 of Set 12 | yeehaw junction
# City not found. Skipping...
# Processing Record 26 of Set 12 | lyubech
# Processing Record 27 of Set 12 | am timan
# Processing Record 28 of Set 12 | araceli
# Processing Record 29 of Set 12 | penzance
# Processing Record 30 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 12 | sal rei
# Processing Record 32 of Set 12 | bilibino
# Processing Record 33 of Set 12 | vesoul
# Processing Record 34 of Set 12 | padang
# Processing Record 35 of Set 12 | pirai do sul
# Processing Record 36 of Set 12 | mangan
# Processing Record 37 of Set 12 | yeppoon
# Processing Record 38 of Set 12 | urucurituba
# Processing Record 39 of Set 12 | bukavu
# Processing Record 40 of Set 12 | mitu
# Processing Record 41 of Set 12 | nabire
# Processing Record 42 of Set 12 | olenegorsk
# Processing Record 43 of Set 12 | antalaha
# Processing Record 44 of Set 12 | liniere
# City not found. Skipping...
# Processing Record 45 of Set 12 | gelibolu
# Processing Record 46 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 47 of Set 12 | ahar
# Processing Record 48 of Set 12 | shurugwi
# Processing Record 49 of Set 12 | sept-iles
# Processing Record 50 of Set 12 | hamilton
# Processing Record 1 of Set 13 | sechura
# Processing Record 2 of Set 13 | ancud
# Processing Record 3 of Set 13 | stephenville
# Processing Record 4 of Set 13 | madera
# Processing Record 5 of Set 13 | dicamay
# Processing Record 6 of Set 13 | ajaccio
# Processing Record 7 of Set 13 | kalemie
# Processing Record 8 of Set 13 | andenes
# Processing Record 9 of Set 13 | peniche
# Processing Record 10 of Set 13 | urumqi
# Processing Record 11 of Set 13 | yarim
# Processing Record 12 of Set 13 | ambilobe
# Processing Record 13 of Set 13 | mamlyutka
# Processing Record 14 of Set 13 | pangody
# Processing Record 15 of Set 13 | thinadhoo
# Processing Record 16 of Set 13 | puerto quijarro
# Processing Record 17 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 18 of Set 13 | oxford
# Processing Record 19 of Set 13 | panorama
# Processing Record 20 of Set 13 | imbituba
# Processing Record 21 of Set 13 | gander
# Processing Record 22 of Set 13 | ambon
# Processing Record 23 of Set 13 | halifax
# Processing Record 24 of Set 13 | mooi river
# City not found. Skipping...
# Processing Record 25 of Set 13 | amapa
# Processing Record 26 of Set 13 | qianguo
# Processing Record 27 of Set 13 | portland
# Processing Record 28 of Set 13 | marawi
# Processing Record 29 of Set 13 | nipawin
# Processing Record 30 of Set 13 | eirunepe
# Processing Record 31 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 32 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 13 | warrington
# Processing Record 34 of Set 13 | kachiry
# Processing Record 35 of Set 13 | rundu
# Processing Record 36 of Set 13 | karamken
# City not found. Skipping...
# Processing Record 37 of Set 13 | bajo baudo
# City not found. Skipping...
# Processing Record 38 of Set 13 | serenje
# Processing Record 39 of Set 13 | dagana
# Processing Record 40 of Set 13 | yanam
# Processing Record 41 of Set 13 | sungai petani
# Processing Record 42 of Set 13 | alzamay
# Processing Record 43 of Set 13 | bereda
# Processing Record 44 of Set 13 | karratha
# Processing Record 45 of Set 13 | middlebury
# Processing Record 46 of Set 13 | griffith
# Processing Record 47 of Set 13 | nuevo progreso
# Processing Record 48 of Set 13 | zhigansk
# Processing Record 49 of Set 13 | neiafu
# Processing Record 50 of Set 13 | lompoc
# Processing Record 1 of Set 14 | heffingen
# Processing Record 2 of Set 14 | salinopolis
# Processing Record 3 of Set 14 | banyo
# Processing Record 4 of Set 14 | blois
# Processing Record 5 of Set 14 | la reforma
# Processing Record 6 of Set 14 | kaeo
# Processing Record 7 of Set 14 | seoni
# Processing Record 8 of Set 14 | henties bay
# Processing Record 9 of Set 14 | miguel auza
# Processing Record 10 of Set 14 | great yarmouth
# Processing Record 11 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 14 | wuwei
# Processing Record 13 of Set 14 | lock haven
# Processing Record 14 of Set 14 | lekoni
# Processing Record 15 of Set 14 | swan river
# Processing Record 16 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 17 of Set 14 | follonica
# Processing Record 18 of Set 14 | ugep
# Processing Record 19 of Set 14 | coihaique
# Processing Record 20 of Set 14 | kanniyakumari
# Processing Record 21 of Set 14 | severomuysk
# Processing Record 22 of Set 14 | nizhnetroitskiy
# Processing Record 23 of Set 14 | hameenlinna
# Processing Record 24 of Set 14 | reims
# Processing Record 25 of Set 14 | houma
# Processing Record 26 of Set 14 | kaohsiung
# Processing Record 27 of Set 14 | baiyin
# Processing Record 28 of Set 14 | sinnamary
# Processing Record 29 of Set 14 | skelleftea
# Processing Record 30 of Set 14 | takoradi
# Processing Record 31 of Set 14 | gold coast
# Processing Record 32 of Set 14 | djibo
# Processing Record 33 of Set 14 | aksu
# Processing Record 34 of Set 14 | bonthe
# Processing Record 35 of Set 14 | noumea
# Processing Record 36 of Set 14 | fort nelson
# Processing Record 37 of Set 14 | winneba
# Processing Record 38 of Set 14 | verkhnevilyuysk
# Processing Record 39 of Set 14 | charters towers
# Processing Record 40 of Set 14 | walla walla
# Processing Record 41 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 14 | bima
# Processing Record 43 of Set 14 | basco
# Processing Record 44 of Set 14 | tulun
# Processing Record 45 of Set 14 | ulladulla
# Processing Record 46 of Set 14 | camocim
# Processing Record 47 of Set 14 | livingstone
# Processing Record 48 of Set 14 | awbari
# Processing Record 49 of Set 14 | solsvik
# City not found. Skipping...
# Processing Record 50 of Set 14 | eenhana
# Processing Record 1 of Set 15 | north platte
# Processing Record 2 of Set 15 | zhanaozen
# Processing Record 3 of Set 15 | along
# Processing Record 4 of Set 15 | vavuniya
# Processing Record 5 of Set 15 | cap malheureux
# Processing Record 6 of Set 15 | atherton
# Processing Record 7 of Set 15 | resistencia
# Processing Record 8 of Set 15 | porto novo
# Processing Record 9 of Set 15 | makrinitsa
# Processing Record 10 of Set 15 | shizunai
# Processing Record 11 of Set 15 | aliwal north
# Processing Record 12 of Set 15 | belyy yar
# Processing Record 13 of Set 15 | muravlenko
# Processing Record 14 of Set 15 | pampierstad
# Processing Record 15 of Set 15 | quebo
# Processing Record 16 of Set 15 | trairi
# Processing Record 17 of Set 15 | turinskaya sloboda
# Processing Record 18 of Set 15 | vanimo
# Processing Record 19 of Set 15 | corn island
# Processing Record 20 of Set 15 | havre-saint-pierre
# Processing Record 21 of Set 15 | isla vista
# Processing Record 22 of Set 15 | bowen
# Processing Record 23 of Set 15 | ust-nera
# Processing Record 24 of Set 15 | labytnangi
# Processing Record 25 of Set 15 | bodmin
# Processing Record 26 of Set 15 | praia da vitoria
# Processing Record 27 of Set 15 | taitung
# Processing Record 28 of Set 15 | kosh-agach
# Processing Record 29 of Set 15 | laguna
# Processing Record 30 of Set 15 | santa cruz
# Processing Record 31 of Set 15 | sakakah
# Processing Record 32 of Set 15 | port hedland
# Processing Record 33 of Set 15 | prior lake
# Processing Record 34 of Set 15 | malpe
# Processing Record 35 of Set 15 | jinchang
# Processing Record 36 of Set 15 | tilichiki
# Processing Record 37 of Set 15 | bethal
# Processing Record 38 of Set 15 | paradwip
# City not found. Skipping...
# Processing Record 39 of Set 15 | gawler
# Processing Record 40 of Set 15 | bandarbeyla
# Processing Record 41 of Set 15 | carbondale
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the city count to confirm sufficient count.
len(city_data)
# Out:
# 675

# %%
#7 Add the data to a new DataFrame.
weather_data_df = pd.DataFrame(city_data)
weather_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Lago Da Pedra  -4.3333  -45.1667     74.89        94          95
# 1        Rikitea -23.1203 -134.9692     80.20        67           1
# 2        Russell  32.3502  -85.1999     60.80        63          90
# 3         Atuona  -9.8000 -139.0333     78.21        78           9
# 4      Cape Town -33.9258   18.4232     66.99        59           0
# 5      Saskylakh  71.9167  114.0833    -39.08        78           2
# 6      Jamestown  42.0970  -79.2353     25.00        63          75
# 7         Barrow  71.2906 -156.7887     -4.00        77           1
# 8        Ushuaia -54.8000  -68.3000     53.60        71          90
# 9      Antsohihy -14.8796   47.9875     74.66        94          79
#
#    Wind Speed Current Description Country
# 0        3.58     overcast clouds      BR
# 1        9.22           clear sky      PF
# 2        9.22     overcast clouds      US
# 3       13.11           clear sky      PF
# 4        6.91           clear sky      ZA
# 5        6.60           clear sky      RU
# 6        2.80       broken clouds      US
# 7       14.97                haze      US
# 8       11.50       moderate rain      AR
# 9        2.55       moderate rain      MG

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
weather_data_df = weather_data_df[new_column_order]
weather_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Lago Da Pedra      BR  -4.3333  -45.1667     74.89        94          95
# 1        Rikitea      PF -23.1203 -134.9692     80.20        67           1
# 2        Russell      US  32.3502  -85.1999     60.80        63          90
# 3         Atuona      PF  -9.8000 -139.0333     78.21        78           9
# 4      Cape Town      ZA -33.9258   18.4232     66.99        59           0
# 5      Saskylakh      RU  71.9167  114.0833    -39.08        78           2
# 6      Jamestown      US  42.0970  -79.2353     25.00        63          75
# 7         Barrow      US  71.2906 -156.7887     -4.00        77           1
# 8        Ushuaia      AR -54.8000  -68.3000     53.60        71          90
# 9      Antsohihy      MG -14.8796   47.9875     74.66        94          79
#
#    Wind Speed Current Description
# 0        3.58     overcast clouds
# 1        9.22           clear sky
# 2        9.22     overcast clouds
# 3       13.11           clear sky
# 4        6.91           clear sky
# 5        6.60           clear sky
# 6        2.80       broken clouds
# 7       14.97                haze
# 8       11.50       moderate rain
# 9        2.55       moderate rain

# %%
#8 Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
weather_data_df.to_csv(output_data_file, index_label="City_ID")
